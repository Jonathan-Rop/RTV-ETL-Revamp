# %%
import pandas as pd
import matplotlib.pyplot as plt
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .appName("silver") \
    .getOrCreate()

# %%
df = spark.read.option("header", "true").csv(r"01_baseline.csv")

# %%
df.columns
# Out:
# ['_c0',
#  'SubmissionDate',
#  'starttime',
#  'endtime',
#  'version',
#  'duration',
#  'survey_start',
#  'intro_start',
#  'district',
#  'Surveyor_Name',
#  'Surveyor_Name2',
#  'hhid_2',
#  'hhid_2_again',
#  'pre_village',
#  'Quartile',
#  'pre_name',
#  'pre_district',
#  'Pre_cluster',
#  'pre_parish',
#  'pre_subcounty',
#  'pre_check',
#  'status',
#  'name_correction',
#  'first_name_corrected',
#  'last_name_corrected',
#  'hhh_fullname',
#  'GPS-Latitude',
#  'GPS-Longitude',
#  'GPS-Altitude',
#  'GPS-Accuracy',
#  'HomesteadPhoto',
#  'consent_1',
#  'consent_2',
#  'refusing',
#  'refusing_1',
#  'refusing_2',
#  'refusing_3',
#  'refusing_4',
#  'refusing_5',
#  'refusing_6',
#  'intro_end',
#  'intro_dur',
#  'hh_demographics_start',
#  'respondent',
#  'hhh_sex',
#  'hhh_age',
#  'hhh_marital_status',
#  'hhh_educ_level',
#  'hhh_read_write',
#  'leadership_head',
#  'head_Leadership_Committee_Name',
#  'head_Leadership_Committee_Name_1',
# ...

# %%
df.describe
# Out:
# <bound method DataFrame.describe of DataFrame[_c0: string, SubmissionDate: string, starttime: string, endtime: string, version: string, duration: string, survey_start: string, intro_start: string, district: string, Surveyor_Name: string, Surveyor_Name2: string, hhid_2: string, hhid_2_again: string, pre_village: string, Quartile: string, pre_name: string, pre_district: string, Pre_cluster: string, pre_parish: string, pre_subcounty: string, pre_check: string, status: string, name_correction: string, first_name_corrected: string, last_name_corrected: string, hhh_fullname: string, GPS-Latitude: string, GPS-Longitude: string, GPS-Altitude: string, GPS-Accuracy: string, HomesteadPhoto: string, consent_1: string, consent_2: string, refusing: string, refusing_1: string, refusing_2: string, refusing_3: string, refusing_4: string, refusing_5: string, refusing_6: string, intro_end: string, intro_dur: string, hh_demographics_start: string, respondent: string, hhh_sex: string, hhh_age: string, hh
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- SubmissionDate: string (nullable = true)
#  |-- starttime: string (nullable = true)
#  |-- endtime: string (nullable = true)
#  |-- version: string (nullable = true)
#  |-- duration: string (nullable = true)
#  |-- survey_start: string (nullable = true)
#  |-- intro_start: string (nullable = true)
#  |-- district: string (nullable = true)
#  |-- Surveyor_Name: string (nullable = true)
#  |-- Surveyor_Name2: string (nullable = true)
#  |-- hhid_2: string (nullable = true)
#  |-- hhid_2_again: string (nullable = true)
#  |-- pre_village: string (nullable = true)
#  |-- Quartile: string (nullable = true)
#  |-- pre_name: string (nullable = true)
#  |-- pre_district: string (nullable = true)
#  |-- Pre_cluster: string (nullable = true)
#  |-- pre_parish: string (nullable = true)
#  |-- pre_subcounty: string (nullable = true)
#  |-- pre_check: string (nullable = true)
#  |-- status: string (nullable = true)
# ...

# %%
from pyspark.sql.functions import sum


df.select('')
